# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_red = pd.read_csv('winequality-red.csv',sep=';')
df_white = pd.read_csv('winequality-white.csv',sep=';')
df_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
r = df_red.shape
w = df_white.shape

# %% [markdown]
# ### creating color array for df_red and df_white

# %%
color_red = np.repeat('red',r[0])
color_white = np.repeat('white',w[0])

# %%
df_red['color'] = color_red
df_white['color'] = color_white

# %% [markdown]
# ### joining the two dataframes

# %%
wine = df_red.append(df_white)
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
wine.to_csv('wine.csv',index=False)

# %%
df = pd.read_csv('wine.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
df.hist(figsize=(15,15));

# %% [markdown]
# alcohol,fixed acidity and volatile acidity seems to skewed to the right

# %%
sns.pairplot(df)

# %% [markdown]
# Alcohol seems to have a positive effect on the quality compared to other variables

# %% [markdown]
# ### Q1: Is a certain type of wine (red or white) associated with higher quality?

# %%
df.groupby(['quality','color']).mean()
# Out:
#                fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality color
# 3       red         8.360000          0.884500     0.171000        2.635000
#         white       7.600000          0.333250     0.336000        6.392500
# 4       red         7.779245          0.693962     0.174151        2.694340
#         white       7.129448          0.381227     0.304233        4.628221
# 5       red         8.167254          0.577041     0.243686        2.528855
#         white       6.933974          0.302011     0.337653        7.334969
# 6       red         8.347179          0.497484     0.273824        2.477194
#         white       6.837671          0.260564     0.338025        6.441606
# 7       red         8.872362          0.403920     0.375176        2.720603
#         white       6.734716          0.262767     0.325625        5.186477
# 8       red         8.566667          0.423333     0.391111        2.577778
# ...

# %%
df.groupby(['quality','color'],as_index=False)['pH'].mean()
# Out:
#     quality  color        pH
# 0         3    red  3.398000
# 1         3  white  3.187500
# 2         4    red  3.381509
# 3         4  white  3.182883
# 4         5    red  3.304949
# 5         5  white  3.168833
# 6         6    red  3.318072
# 7         6  white  3.188599
# 8         7    red  3.290754
# 9         7  white  3.213898
# 10        8    red  3.267222
# 11        8  white  3.218686
# 12        9  white  3.308000

# %%
df.groupby(['color'],as_index=False)['quality'].mean()
# Out:
#    color   quality
# 0    red  5.636023
# 1  white  5.877909

# %% [markdown]
# white wines appears to have higher quality than red wines

# %% [markdown]
# ### Q2: What level of acidity (pH value) receives the highest average rating?

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
# Bin edges that will be used to "cut" the data into groups
bin_edges = [2.72,3.11,3.21,3.32,4.01]

# %%
# Labels for the four acidity level groups
bin_names = ['high','moderately_high','medium','low']
# lower pH => more acidic

# %%
# Creates acidity_levels column
df['acidic_level'] = pd.cut(df['pH'],bin_edges,labels=bin_names)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color     acidic_level
# 0      9.4        5   red              low
# ...

# %%
df.groupby(['acidic_level'],as_index=False)['quality'].mean()
# Out:
#       acidic_level   quality
# 0             high  5.783343
# 1  moderately_high  5.784540
# 2           medium  5.850832
# 3              low  5.859593

# %% [markdown]
# higher quality wine tend to be less acidic

# %% [markdown]
# ### Q3: Do wines with higher alcoholic content receive better ratings?

# %%
df['alcohol'].median()
# Out:
# 10.3

# %%
low_alcohol = df.query('alcohol <= 10.3')
high_alcohol = df.query('alcohol > 10.3')

# %%
# ensure these queries included each sample exactly once
num_samples = df.shape[0]
num_samples == low_alcohol['quality'].count() + high_alcohol['quality'].count()
# Out:
# True

# %%
# mean quality rating for the low alcohol and high alcohol groups
low_alcohol['quality'].mean(),high_alcohol['quality'].mean()
# Out:
# (5.484673748103186, 6.161773891317926)

# %% [markdown]
# we see that wines with higher alcohol level tend to be of higher quality.

# %% [markdown]
# ### Q4: Do sweeter wines receive better ratings?

# %%
df['residual sugar'].median()
# Out:
# 3.0

# %%
# select samples with residual sugar less than the median
low_sugar = df.query('`residual sugar` <= 3')

# select samples with residual sugar greater than or equal to the median
high_sugar = df.query('`residual sugar` > 3')

# ensure these queries included each sample exactly once
num_samples == low_sugar['quality'].count() + high_sugar['quality'].count() # should be True
# Out:
# True

# %%
# get mean quality rating for the low sugar and high sugar groups
low_sugar['quality'].mean(),high_sugar['quality'].mean()
# Out:
# (5.8075864178647905, 5.829306071871128)

# %% [markdown]
# ### Answering using Visualization

# %% [markdown]
# #### Q: Do wines with higher alcoholic content receive better ratings

# %%
# Use query to select each group and get its mean quality
median = df['alcohol'].median()
low = df.query('alcohol < {}'.format(median))
high = df.query('alcohol >= {}'.format(median))

mean_quality_low = low['quality'].mean()
mean_quality_high = high['quality'].mean()

# %%
locations = [1,2]
height = [mean_quality_low,mean_quality_high]
labels = ['low','high']
plt.bar(locations,height,tick_label=labels)
plt.title('Average Quality Ratings by Alcohol Content')
plt.xlabel('Alcohol Content')
plt.ylabel('Average Quality Rating');

# %% [markdown]
# #### Q: What level of acidity receives the highest average rating?

# %%
# Use groupby to get the mean quality for each acidity level
acidity_level_quality_means = df.groupby('acidic_level').quality.mean()
acidity_level_quality_means
# Out:
# acidic_level
# high               5.783343
# moderately_high    5.784540
# medium             5.850832
# low                5.859593
# Name: quality, dtype: float64

# %%
# Create a bar chart with proper labels
locations = [4, 1, 2, 3]  # reorder values above to go from low to high
heights = acidity_level_quality_means

# labels = ['Low', 'Medium', 'Moderately High', 'High']
labels = acidity_level_quality_means.index.str.replace('_', ' ').str.title() # alternative to commented out line above

plt.bar(locations, heights, tick_label=labels)
plt.title('Average Quality Ratings by Acidity Level')
plt.xlabel('Acidity Level')
plt.ylabel('Average Quality Rating');

# %%
# get counts for each rating and color
color_counts = df.groupby(['color', 'quality']).count()['pH']
color_counts
# Out:
# color  quality
# red    3            10
#        4            53
#        5           681
#        6           638
#        7           199
#        8            18
# white  3            20
#        4           163
#        5          1457
#        6          2198
#        7           880
#        8           175
#        9             5
# Name: pH, dtype: int64

# %%
# get total counts for each color
color_totals = df.groupby('color').count()['pH']
color_totals
# Out:
# color
# red      1599
# white    4898
# Name: pH, dtype: int64

# %%
# get proportions by dividing red rating counts by total # of red samples
red_proportions = color_counts['red'] / color_totals['red']
red_proportions
# Out:
# quality
# 3    0.006254
# 4    0.033146
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 8    0.011257
# Name: pH, dtype: float64

# %%
red_proportions['9'] = 0
red_proportions
# Out:
# quality
# 3    0.006254
# 4    0.033146
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 8    0.011257
# 9    0.000000
# Name: pH, dtype: float64

# %%
# get proportions by dividing white rating counts by total # of white samples
white_proportions = color_counts['white'] / color_totals['white']
white_proportions
# Out:
# quality
# 3    0.004083
# 4    0.033279
# 5    0.297468
# 6    0.448755
# 7    0.179665
# 8    0.035729
# 9    0.001021
# Name: pH, dtype: float64

# %%
ind = np.arange(len(red_proportions))  # the x locations for the groups
width = 0.35    # the width of the bars

# %%
# plot bars
red_bars = plt.bar(ind, red_proportions, width, color='r', alpha=.7, label='Red Wine')
white_bars = plt.bar(ind + width, white_proportions, width, color='w', alpha=.7, label='White Wine')

# title and labels
plt.ylabel('Proportion')
plt.xlabel('Quality')
plt.title('Proportion by Wine Color and Quality')
locations = ind + width / 2  # xtick locations
labels = ['3', '4', '5', '6', '7', '8', '9']  # xtick labels
plt.xticks(locations, labels)

# legend
plt.legend()

# %%
red_proportions['9'] = 0
red_proportions
# Out:
# quality
# 3    0.006254
# 4    0.033146
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 8    0.011257
# 9    0.000000
# Name: pH, dtype: float64
